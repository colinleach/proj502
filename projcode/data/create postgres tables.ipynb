# %%
import pandas as pd

from logger import Logger
from db import DB

# %%
mapping = 'gz2_hart16_clean.txt'

# %%
data = pd.read_csv(mapping, sep='\t')
data = data.rename(columns={"name": "gzname"})

# %%
data.head(10)
# Out:
#                   gzname     type  length  \
# 0              specobjid   bigint       8
# 1               dr8objid   bigint       8
# 2               dr7objid   bigint       8
# 3                     ra     real       4
# 4                    dec     real       4
# 5               rastring  varchar      11
# 6              decstring  varchar      11
# 7                 sample  varchar      20
# 8              gz2_class  varchar      20
# 9  total_classifications      int       4
#
#                                          description
# 0                                                NaN
# 1                                                NaN
# 2  match to the DR7 objID for the corresponding n...
# 3         right ascension [J2000.0], decimal degrees
# 4             declination [J2000.0], decimal degrees
# 5             right ascension [J2000.0], sexagesimal
# 6                 declination [J2000.0], sexagesimal
# 7                          sub-sample identification
# 8  shorthand string for the most common consensus...
# 9    total number of classifications for this galaxy

# %%
data.shape
# Out:
# (233, 4)

# %%
def translate_type(gztype, length):
    if gztype == 'bigint':
        return 'bigint'
    if gztype == 'real':
        return 'real'
    if gztype == 'int':
        return 'integer'
    if gztype == 'float':
        return 'double precision'
    if gztype == 'real':
        return 'varchar'
    if gztype == 'varchar':
        return f'character varying({length})'
    return f'***** {gztype} not recognized'

# %%
fieldlist = [f'{rec.gzname} {translate_type(rec.type, rec.length)}'
             for index, rec in data.iterrows()]

# %%
fields = ',\n'.join(fieldlist)
print(fields)
# Out:
# specobjid bigint,
# dr8objid bigint,
# dr7objid bigint,
# ra real,
# dec real,
# rastring character varying(11),
# decstring character varying(11),
# sample character varying(20),
# gz2_class character varying(20),
# total_classifications integer,
# total_votes integer,
# t01_smooth_or_features_a01_smooth_count integer,
# t01_smooth_or_features_a01_smooth_weight double precision,
# t01_smooth_or_features_a01_smooth_fraction double precision,
# t01_smooth_or_features_a01_smooth_weighted_fraction double precision,
# t01_smooth_or_features_a01_smooth_debiased double precision,
# t01_smooth_or_features_a01_smooth_flag integer,
# t01_smooth_or_features_a02_features_or_disk_count integer,
# t01_smooth_or_features_a02_features_or_disk_weight double precision,
# t01_smooth_or_features_a02_features_or_disk_fraction double precision,
# t01_smooth_or_features_a02_features_or_disk_weighted_fraction double precision,
# t01_smooth_or_features_a02_features_or_disk_debiased double precision,
# t01_smooth_or_features_a02_features_or_disk_flag integer,
# t01_smooth_or_features_a03_star_or_artifact_count integer,
# t01_smooth_or_features_a03_star_or_artifact_weight double precision,
# t01_smooth_or_features_a03_star_or_artifact_fraction double precision,
# t01_smooth_or_features_a03_star_or_artifact_weighted_fraction double precision,
# t01_smooth_or_features_a03_star_or_artifact_debiased double precision,
# t01_smooth_or_features_a03_star_or_artifact_flag integer,
# t02_edgeon_a04_yes_count integer,
# t02_edgeon_a04_yes_weight double precision,
# t02_edgeon_a04_yes_fraction double precision,
# t02_edgeon_a04_yes_weighted_fraction double precision,
# t02_edgeon_a04_yes_debiased double precision,
# t02_edgeon_a04_yes_flag integer,
# t02_edgeon_a05_no_count integer,
# t02_edgeon_a05_no_weight double precision,
# t02_edgeon_a05_no_fraction double precision,
# t02_edgeon_a05_no_weighted_fraction double precision,
# t02_edgeon_a05_no_debiased double precision,
# t02_edgeon_a05_no_flag integer,
# t03_bar_a06_bar_count integer,
# t03_bar_a06_bar_weight double precision,
# t03_bar_a06_bar_fraction double precision,
# t03_bar_a06_bar_weighted_fraction double precision,
# t03_bar_a06_bar_debiased double precision,
# t03_bar_a06_bar_flag integer,
# t03_bar_a07_no_bar_count integer,
# t03_bar_a07_no_bar_weight double precision,
# t03_bar_a07_no_bar_fraction double precision,
# t03_bar_a07_no_bar_weighted_fraction double precision,
# t03_bar_a07_no_bar_debiased double precision,
# t03_bar_a07_no_bar_flag integer,
# t04_spiral_a08_spiral_count integer,
# t04_spiral_a08_spiral_weight double precision,
# t04_spiral_a08_spiral_fraction double precision,
# t04_spiral_a08_spiral_weighted_fraction double precision,
# t04_spiral_a08_spiral_debiased double precision,
# t04_spiral_a08_spiral_flag integer,
# t04_spiral_a09_no_spiral_count integer,
# t04_spiral_a09_no_spiral_weight double precision,
# t04_spiral_a09_no_spiral_fraction double precision,
# t04_spiral_a09_no_spiral_weighted_fraction double precision,
# t04_spiral_a09_no_spiral_debiased double precision,
# t04_spiral_a09_no_spiral_flag integer,
# t05_bulge_prominence_a10_no_bulge_count integer,
# t05_bulge_prominence_a10_no_bulge_weight double precision,
# t05_bulge_prominence_a10_no_bulge_fraction double precision,
# t05_bulge_prominence_a10_no_bulge_weighted_fraction double precision,
# t05_bulge_prominence_a10_no_bulge_debiased double precision,
# t05_bulge_prominence_a10_no_bulge_flag integer,
# t05_bulge_prominence_a11_just_noticeable_count integer,
# t05_bulge_prominence_a11_just_noticeable_weight double precision,
# t05_bulge_prominence_a11_just_noticeable_fraction double precision,
# t05_bulge_prominence_a11_just_noticeable_weighted_fraction double precision,
# t05_bulge_prominence_a11_just_noticeable_debiased double precision,
# t05_bulge_prominence_a11_just_noticeable_flag integer,
# t05_bulge_prominence_a12_obvious_count integer,
# t05_bulge_prominence_a12_obvious_weight double precision,
# t05_bulge_prominence_a12_obvious_fraction double precision,
# t05_bulge_prominence_a12_obvious_weighted_fraction double precision,
# t05_bulge_prominence_a12_obvious_debiased double precision,
# t05_bulge_prominence_a12_obvious_flag integer,
# t05_bulge_prominence_a13_dominant_count integer,
# t05_bulge_prominence_a13_dominant_weight double precision,
# t05_bulge_prominence_a13_dominant_fraction double precision,
# t05_bulge_prominence_a13_dominant_weighted_fraction double precision,
# t05_bulge_prominence_a13_dominant_debiased double precision,
# t05_bulge_prominence_a13_dominant_flag integer,
# t06_odd_a14_yes_count integer,
# t06_odd_a14_yes_weight double precision,
# t06_odd_a14_yes_fraction double precision,
# t06_odd_a14_yes_weighted_fraction double precision,
# t06_odd_a14_yes_debiased double precision,
# t06_odd_a14_yes_flag integer,
# t06_odd_a15_no_count integer,
# t06_odd_a15_no_weight double precision,
# t06_odd_a15_no_fraction double precision,
# t06_odd_a15_no_weighted_fraction double precision,
# t06_odd_a15_no_debiased double precision,
# t06_odd_a15_no_flag integer,
# t07_rounded_a16_completely_round_count integer,
# t07_rounded_a16_completely_round_weight double precision,
# t07_rounded_a16_completely_round_fraction double precision,
# t07_rounded_a16_completely_round_weighted_fraction double precision,
# t07_rounded_a16_completely_round_debiased double precision,
# t07_rounded_a16_completely_round_flag integer,
# t07_rounded_a17_in_between_count integer,
# t07_rounded_a17_in_between_weight double precision,
# t07_rounded_a17_in_between_fraction double precision,
# t07_rounded_a17_in_between_weighted_fraction double precision,
# t07_rounded_a17_in_between_debiased double precision,
# t07_rounded_a17_in_between_flag integer,
# t07_rounded_a18_cigar_shaped_count integer,
# t07_rounded_a18_cigar_shaped_weight double precision,
# t07_rounded_a18_cigar_shaped_fraction double precision,
# t07_rounded_a18_cigar_shaped_weighted_fraction double precision,
# t07_rounded_a18_cigar_shaped_debiased double precision,
# t07_rounded_a18_cigar_shaped_flag integer,
# t08_odd_feature_a19_ring_count integer,
# t08_odd_feature_a19_ring_weight double precision,
# t08_odd_feature_a19_ring_fraction double precision,
# t08_odd_feature_a19_ring_weighted_fraction double precision,
# t08_odd_feature_a19_ring_debiased double precision,
# t08_odd_feature_a19_ring_flag integer,
# t08_odd_feature_a20_lens_or_arc_count integer,
# t08_odd_feature_a20_lens_or_arc_weight double precision,
# t08_odd_feature_a20_lens_or_arc_fraction double precision,
# t08_odd_feature_a20_lens_or_arc_weighted_fraction double precision,
# t08_odd_feature_a20_lens_or_arc_debiased double precision,
# t08_odd_feature_a20_lens_or_arc_flag integer,
# t08_odd_feature_a21_disturbed_count integer,
# t08_odd_feature_a21_disturbed_weight double precision,
# t08_odd_feature_a21_disturbed_fraction double precision,
# t08_odd_feature_a21_disturbed_weighted_fraction double precision,
# t08_odd_feature_a21_disturbed_debiased double precision,
# t08_odd_feature_a21_disturbed_flag integer,
# t08_odd_feature_a22_irregular_count integer,
# t08_odd_feature_a22_irregular_weight double precision,
# t08_odd_feature_a22_irregular_fraction double precision,
# t08_odd_feature_a22_irregular_weighted_fraction double precision,
# t08_odd_feature_a22_irregular_debiased double precision,
# t08_odd_feature_a22_irregular_flag integer,
# t08_odd_feature_a23_other_count integer,
# t08_odd_feature_a23_other_weight double precision,
# t08_odd_feature_a23_other_fraction double precision,
# t08_odd_feature_a23_other_weighted_fraction double precision,
# t08_odd_feature_a23_other_debiased double precision,
# t08_odd_feature_a23_other_flag integer,
# t08_odd_feature_a24_merger_count integer,
# t08_odd_feature_a24_merger_weight double precision,
# t08_odd_feature_a24_merger_fraction double precision,
# t08_odd_feature_a24_merger_weighted_fraction double precision,
# t08_odd_feature_a24_merger_debiased double precision,
# t08_odd_feature_a24_merger_flag integer,
# t08_odd_feature_a38_dust_lane_count integer,
# t08_odd_feature_a38_dust_lane_weight double precision,
# t08_odd_feature_a38_dust_lane_fraction double precision,
# t08_odd_feature_a38_dust_lane_weighted_fraction double precision,
# t08_odd_feature_a38_dust_lane_debiased double precision,
# t08_odd_feature_a38_dust_lane_flag integer,
# t09_bulge_shape_a25_rounded_count integer,
# t09_bulge_shape_a25_rounded_weight double precision,
# t09_bulge_shape_a25_rounded_fraction double precision,
# t09_bulge_shape_a25_rounded_weighted_fraction double precision,
# t09_bulge_shape_a25_rounded_debiased double precision,
# t09_bulge_shape_a25_rounded_flag integer,
# t09_bulge_shape_a26_boxy_count integer,
# t09_bulge_shape_a26_boxy_weight double precision,
# t09_bulge_shape_a26_boxy_fraction double precision,
# t09_bulge_shape_a26_boxy_weighted_fraction double precision,
# t09_bulge_shape_a26_boxy_debiased double precision,
# t09_bulge_shape_a26_boxy_flag integer,
# t09_bulge_shape_a27_no_bulge_count integer,
# t09_bulge_shape_a27_no_bulge_weight double precision,
# t09_bulge_shape_a27_no_bulge_fraction double precision,
# t09_bulge_shape_a27_no_bulge_weighted_fraction double precision,
# t09_bulge_shape_a27_no_bulge_debiased double precision,
# t09_bulge_shape_a27_no_bulge_flag integer,
# t10_arms_winding_a28_tight_count integer,
# t10_arms_winding_a28_tight_weight double precision,
# t10_arms_winding_a28_tight_fraction double precision,
# t10_arms_winding_a28_tight_weighted_fraction double precision,
# t10_arms_winding_a28_tight_debiased double precision,
# t10_arms_winding_a28_tight_flag integer,
# t10_arms_winding_a29_medium_count integer,
# t10_arms_winding_a29_medium_weight double precision,
# t10_arms_winding_a29_medium_fraction double precision,
# t10_arms_winding_a29_medium_weighted_fraction double precision,
# t10_arms_winding_a29_medium_debiased double precision,
# t10_arms_winding_a29_medium_flag integer,
# t10_arms_winding_a30_loose_count integer,
# t10_arms_winding_a30_loose_weight double precision,
# t10_arms_winding_a30_loose_fraction double precision,
# t10_arms_winding_a30_loose_weighted_fraction double precision,
# t10_arms_winding_a30_loose_debiased double precision,
# t10_arms_winding_a30_loose_flag integer,
# t11_arms_number_a31_1_count integer,
# t11_arms_number_a31_1_weight double precision,
# t11_arms_number_a31_1_fraction double precision,
# t11_arms_number_a31_1_weighted_fraction double precision,
# t11_arms_number_a31_1_debiased double precision,
# t11_arms_number_a31_1_flag integer,
# t11_arms_number_a32_2_count integer,
# t11_arms_number_a32_2_weight double precision,
# t11_arms_number_a32_2_fraction double precision,
# t11_arms_number_a32_2_weighted_fraction double precision,
# t11_arms_number_a32_2_debiased double precision,
# t11_arms_number_a32_2_flag integer,
# t11_arms_number_a33_3_count integer,
# t11_arms_number_a33_3_weight double precision,
# t11_arms_number_a33_3_fraction double precision,
# t11_arms_number_a33_3_weighted_fraction double precision,
# t11_arms_number_a33_3_debiased double precision,
# t11_arms_number_a33_3_flag integer,
# t11_arms_number_a34_4_count integer,
# t11_arms_number_a34_4_weight double precision,
# t11_arms_number_a34_4_fraction double precision,
# t11_arms_number_a34_4_weighted_fraction double precision,
# t11_arms_number_a34_4_debiased double precision,
# t11_arms_number_a34_4_flag integer,
# t11_arms_number_a36_more_than_4_count integer,
# t11_arms_number_a36_more_than_4_weight double precision,
# t11_arms_number_a36_more_than_4_fraction double precision,
# t11_arms_number_a36_more_than_4_weighted_fraction double precision,
# t11_arms_number_a36_more_than_4_debiased double precision,
# t11_arms_number_a36_more_than_4_flag integer,
# t11_arms_number_a37_cant_tell_count integer,
# t11_arms_number_a37_cant_tell_weight double precision,
# t11_arms_number_a37_cant_tell_fraction double precision,
# t11_arms_number_a37_cant_tell_weighted_fraction double precision,
# t11_arms_number_a37_cant_tell_debiased double precision,
# t11_arms_number_a37_cant_tell_flag integer

# %%
sql = f"""
-- DROP TABLE IF EXISTS public.gz2data;

CREATE TABLE public.gz2data
(
    {fields},
    PRIMARY KEY (dr7objid)
);

ALTER TABLE IF EXISTS public.gz2data
    OWNER to python;"""

# %%
print(sql)
# Out:
# -- DROP TABLE IF EXISTS public.gz2data;
#
# CREATE TABLE public.gz2data
# (
#     specobjid bigint,
# dr8objid bigint,
# dr7objid bigint,
# ra real,
# dec real,
# rastring character varying(11),
# decstring character varying(11),
# sample character varying(20),
# gz2_class character varying(20),
# total_classifications integer,
# total_votes integer,
# t01_smooth_or_features_a01_smooth_count integer,
# t01_smooth_or_features_a01_smooth_weight double precision,
# t01_smooth_or_features_a01_smooth_fraction double precision,
# t01_smooth_or_features_a01_smooth_weighted_fraction double precision,
# t01_smooth_or_features_a01_smooth_debiased double precision,
# t01_smooth_or_features_a01_smooth_flag integer,
# t01_smooth_or_features_a02_features_or_disk_count integer,
# t01_smooth_or_features_a02_features_or_disk_weight double precision,
# t01_smooth_or_features_a02_features_or_disk_fraction double precision,
# t01_smooth_or_features_a02_features_or_disk_weighted_fraction double precision,
# t01_smooth_or_features_a02_features_or_disk_debiased double precision,
# t01_smooth_or_features_a02_features_or_disk_flag integer,
# t01_smooth_or_features_a03_star_or_artifact_count integer,
# t01_smooth_or_features_a03_star_or_artifact_weight double precision,
# t01_smooth_or_features_a03_star_or_artifact_fraction double precision,
# t01_smooth_or_features_a03_star_or_artifact_weighted_fraction double precision,
# t01_smooth_or_features_a03_star_or_artifact_debiased double precision,
# t01_smooth_or_features_a03_star_or_artifact_flag integer,
# t02_edgeon_a04_yes_count integer,
# t02_edgeon_a04_yes_weight double precision,
# t02_edgeon_a04_yes_fraction double precision,
# t02_edgeon_a04_yes_weighted_fraction double precision,
# t02_edgeon_a04_yes_debiased double precision,
# t02_edgeon_a04_yes_flag integer,
# t02_edgeon_a05_no_count integer,
# t02_edgeon_a05_no_weight double precision,
# t02_edgeon_a05_no_fraction double precision,
# t02_edgeon_a05_no_weighted_fraction double precision,
# t02_edgeon_a05_no_debiased double precision,
# t02_edgeon_a05_no_flag integer,
# t03_bar_a06_bar_count integer,
# t03_bar_a06_bar_weight double precision,
# t03_bar_a06_bar_fraction double precision,
# t03_bar_a06_bar_weighted_fraction double precision,
# t03_bar_a06_bar_debiased double precision,
# t03_bar_a06_bar_flag integer,
# t03_bar_a07_no_bar_count integer,
# t03_bar_a07_no_bar_weight double precision,
# t03_bar_a07_no_bar_fraction double precision,
# t03_bar_a07_no_bar_weighted_fraction double precision,
# t03_bar_a07_no_bar_debiased double precision,
# t03_bar_a07_no_bar_flag integer,
# t04_spiral_a08_spiral_count integer,
# t04_spiral_a08_spiral_weight double precision,
# t04_spiral_a08_spiral_fraction double precision,
# t04_spiral_a08_spiral_weighted_fraction double precision,
# t04_spiral_a08_spiral_debiased double precision,
# t04_spiral_a08_spiral_flag integer,
# t04_spiral_a09_no_spiral_count integer,
# t04_spiral_a09_no_spiral_weight double precision,
# t04_spiral_a09_no_spiral_fraction double precision,
# t04_spiral_a09_no_spiral_weighted_fraction double precision,
# t04_spiral_a09_no_spiral_debiased double precision,
# t04_spiral_a09_no_spiral_flag integer,
# t05_bulge_prominence_a10_no_bulge_count integer,
# t05_bulge_prominence_a10_no_bulge_weight double precision,
# t05_bulge_prominence_a10_no_bulge_fraction double precision,
# t05_bulge_prominence_a10_no_bulge_weighted_fraction double precision,
# t05_bulge_prominence_a10_no_bulge_debiased double precision,
# t05_bulge_prominence_a10_no_bulge_flag integer,
# t05_bulge_prominence_a11_just_noticeable_count integer,
# t05_bulge_prominence_a11_just_noticeable_weight double precision,
# t05_bulge_prominence_a11_just_noticeable_fraction double precision,
# t05_bulge_prominence_a11_just_noticeable_weighted_fraction double precision,
# t05_bulge_prominence_a11_just_noticeable_debiased double precision,
# t05_bulge_prominence_a11_just_noticeable_flag integer,
# t05_bulge_prominence_a12_obvious_count integer,
# t05_bulge_prominence_a12_obvious_weight double precision,
# t05_bulge_prominence_a12_obvious_fraction double precision,
# t05_bulge_prominence_a12_obvious_weighted_fraction double precision,
# t05_bulge_prominence_a12_obvious_debiased double precision,
# t05_bulge_prominence_a12_obvious_flag integer,
# t05_bulge_prominence_a13_dominant_count integer,
# t05_bulge_prominence_a13_dominant_weight double precision,
# t05_bulge_prominence_a13_dominant_fraction double precision,
# t05_bulge_prominence_a13_dominant_weighted_fraction double precision,
# t05_bulge_prominence_a13_dominant_debiased double precision,
# t05_bulge_prominence_a13_dominant_flag integer,
# t06_odd_a14_yes_count integer,
# t06_odd_a14_yes_weight double precision,
# t06_odd_a14_yes_fraction double precision,
# t06_odd_a14_yes_weighted_fraction double precision,
# t06_odd_a14_yes_debiased double precision,
# t06_odd_a14_yes_flag integer,
# t06_odd_a15_no_count integer,
# t06_odd_a15_no_weight double precision,
# t06_odd_a15_no_fraction double precision,
# t06_odd_a15_no_weighted_fraction double precision,
# t06_odd_a15_no_debiased double precision,
# t06_odd_a15_no_flag integer,
# t07_rounded_a16_completely_round_count integer,
# t07_rounded_a16_completely_round_weight double precision,
# t07_rounded_a16_completely_round_fraction double precision,
# t07_rounded_a16_completely_round_weighted_fraction double precision,
# t07_rounded_a16_completely_round_debiased double precision,
# t07_rounded_a16_completely_round_flag integer,
# t07_rounded_a17_in_between_count integer,
# t07_rounded_a17_in_between_weight double precision,
# t07_rounded_a17_in_between_fraction double precision,
# t07_rounded_a17_in_between_weighted_fraction double precision,
# t07_rounded_a17_in_between_debiased double precision,
# t07_rounded_a17_in_between_flag integer,
# t07_rounded_a18_cigar_shaped_count integer,
# t07_rounded_a18_cigar_shaped_weight double precision,
# t07_rounded_a18_cigar_shaped_fraction double precision,
# t07_rounded_a18_cigar_shaped_weighted_fraction double precision,
# t07_rounded_a18_cigar_shaped_debiased double precision,
# t07_rounded_a18_cigar_shaped_flag integer,
# t08_odd_feature_a19_ring_count integer,
# t08_odd_feature_a19_ring_weight double precision,
# t08_odd_feature_a19_ring_fraction double precision,
# t08_odd_feature_a19_ring_weighted_fraction double precision,
# t08_odd_feature_a19_ring_debiased double precision,
# t08_odd_feature_a19_ring_flag integer,
# t08_odd_feature_a20_lens_or_arc_count integer,
# t08_odd_feature_a20_lens_or_arc_weight double precision,
# t08_odd_feature_a20_lens_or_arc_fraction double precision,
# t08_odd_feature_a20_lens_or_arc_weighted_fraction double precision,
# t08_odd_feature_a20_lens_or_arc_debiased double precision,
# t08_odd_feature_a20_lens_or_arc_flag integer,
# t08_odd_feature_a21_disturbed_count integer,
# t08_odd_feature_a21_disturbed_weight double precision,
# t08_odd_feature_a21_disturbed_fraction double precision,
# t08_odd_feature_a21_disturbed_weighted_fraction double precision,
# t08_odd_feature_a21_disturbed_debiased double precision,
# t08_odd_feature_a21_disturbed_flag integer,
# t08_odd_feature_a22_irregular_count integer,
# t08_odd_feature_a22_irregular_weight double precision,
# t08_odd_feature_a22_irregular_fraction double precision,
# t08_odd_feature_a22_irregular_weighted_fraction double precision,
# t08_odd_feature_a22_irregular_debiased double precision,
# t08_odd_feature_a22_irregular_flag integer,
# t08_odd_feature_a23_other_count integer,
# t08_odd_feature_a23_other_weight double precision,
# t08_odd_feature_a23_other_fraction double precision,
# t08_odd_feature_a23_other_weighted_fraction double precision,
# t08_odd_feature_a23_other_debiased double precision,
# t08_odd_feature_a23_other_flag integer,
# t08_odd_feature_a24_merger_count integer,
# t08_odd_feature_a24_merger_weight double precision,
# t08_odd_feature_a24_merger_fraction double precision,
# t08_odd_feature_a24_merger_weighted_fraction double precision,
# t08_odd_feature_a24_merger_debiased double precision,
# t08_odd_feature_a24_merger_flag integer,
# t08_odd_feature_a38_dust_lane_count integer,
# t08_odd_feature_a38_dust_lane_weight double precision,
# t08_odd_feature_a38_dust_lane_fraction double precision,
# t08_odd_feature_a38_dust_lane_weighted_fraction double precision,
# t08_odd_feature_a38_dust_lane_debiased double precision,
# t08_odd_feature_a38_dust_lane_flag integer,
# t09_bulge_shape_a25_rounded_count integer,
# t09_bulge_shape_a25_rounded_weight double precision,
# t09_bulge_shape_a25_rounded_fraction double precision,
# t09_bulge_shape_a25_rounded_weighted_fraction double precision,
# t09_bulge_shape_a25_rounded_debiased double precision,
# t09_bulge_shape_a25_rounded_flag integer,
# t09_bulge_shape_a26_boxy_count integer,
# t09_bulge_shape_a26_boxy_weight double precision,
# t09_bulge_shape_a26_boxy_fraction double precision,
# t09_bulge_shape_a26_boxy_weighted_fraction double precision,
# t09_bulge_shape_a26_boxy_debiased double precision,
# t09_bulge_shape_a26_boxy_flag integer,
# t09_bulge_shape_a27_no_bulge_count integer,
# t09_bulge_shape_a27_no_bulge_weight double precision,
# t09_bulge_shape_a27_no_bulge_fraction double precision,
# t09_bulge_shape_a27_no_bulge_weighted_fraction double precision,
# t09_bulge_shape_a27_no_bulge_debiased double precision,
# t09_bulge_shape_a27_no_bulge_flag integer,
# t10_arms_winding_a28_tight_count integer,
# t10_arms_winding_a28_tight_weight double precision,
# t10_arms_winding_a28_tight_fraction double precision,
# t10_arms_winding_a28_tight_weighted_fraction double precision,
# t10_arms_winding_a28_tight_debiased double precision,
# t10_arms_winding_a28_tight_flag integer,
# t10_arms_winding_a29_medium_count integer,
# t10_arms_winding_a29_medium_weight double precision,
# t10_arms_winding_a29_medium_fraction double precision,
# t10_arms_winding_a29_medium_weighted_fraction double precision,
# t10_arms_winding_a29_medium_debiased double precision,
# t10_arms_winding_a29_medium_flag integer,
# t10_arms_winding_a30_loose_count integer,
# t10_arms_winding_a30_loose_weight double precision,
# t10_arms_winding_a30_loose_fraction double precision,
# t10_arms_winding_a30_loose_weighted_fraction double precision,
# t10_arms_winding_a30_loose_debiased double precision,
# t10_arms_winding_a30_loose_flag integer,
# t11_arms_number_a31_1_count integer,
# t11_arms_number_a31_1_weight double precision,
# t11_arms_number_a31_1_fraction double precision,
# t11_arms_number_a31_1_weighted_fraction double precision,
# t11_arms_number_a31_1_debiased double precision,
# t11_arms_number_a31_1_flag integer,
# t11_arms_number_a32_2_count integer,
# t11_arms_number_a32_2_weight double precision,
# t11_arms_number_a32_2_fraction double precision,
# t11_arms_number_a32_2_weighted_fraction double precision,
# t11_arms_number_a32_2_debiased double precision,
# t11_arms_number_a32_2_flag integer,
# t11_arms_number_a33_3_count integer,
# t11_arms_number_a33_3_weight double precision,
# t11_arms_number_a33_3_fraction double precision,
# t11_arms_number_a33_3_weighted_fraction double precision,
# t11_arms_number_a33_3_debiased double precision,
# t11_arms_number_a33_3_flag integer,
# t11_arms_number_a34_4_count integer,
# t11_arms_number_a34_4_weight double precision,
# t11_arms_number_a34_4_fraction double precision,
# t11_arms_number_a34_4_weighted_fraction double precision,
# t11_arms_number_a34_4_debiased double precision,
# t11_arms_number_a34_4_flag integer,
# t11_arms_number_a36_more_than_4_count integer,
# t11_arms_number_a36_more_than_4_weight double precision,
# t11_arms_number_a36_more_than_4_fraction double precision,
# t11_arms_number_a36_more_than_4_weighted_fraction double precision,
# t11_arms_number_a36_more_than_4_debiased double precision,
# t11_arms_number_a36_more_than_4_flag integer,
# t11_arms_number_a37_cant_tell_count integer,
# t11_arms_number_a37_cant_tell_weight double precision,
# t11_arms_number_a37_cant_tell_fraction double precision,
# t11_arms_number_a37_cant_tell_weighted_fraction double precision,
# t11_arms_number_a37_cant_tell_debiased double precision,
# t11_arms_number_a37_cant_tell_flag integer,
#     PRIMARY KEY (dr7objid)
# );
#
# ALTER TABLE IF EXISTS public.gz2data
#     OWNER to python;

# %%
pg = DB()

# %%
pg.run_admin("DROP TABLE IF EXISTS public.gz2data")
pg.run_admin(sql)
# pg.run_admin("""ALTER TABLE IF EXISTS public.gz2data
#     ALTER COLUMN dr8objid DROP NOT NULL;""")

# %%
pg.run_count('gz2data')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [27], in <module>
# ----> 1 pg.run_count('gz2data')
#
# File ~/code/galaxy-zoo-bayesian-cnn/data/db.py:64, in DB.run_count(self, table)
#      56 """
#      57 Get number of records in table
#      58
#      59 :param table: postgres table name in current database
#      60 :return: count (int)
#      61 """
#      63 self.cursor.execute(f"select count(*) from {table}")
# ---> 64 return self.cursor.fetch()
#
# AttributeError: 'psycopg2.extensions.cursor' object has no attribute 'fetch'

# %%
names = ','.join(list(data.gzname))
fname = '/home/colin/data/ssd240/zoo2MainSpecz.csv'

# %%
uploadsql = f"""COPY gz2data({names})
FROM '{fname}'
DELIMITER ','
CSV HEADER;"""

# %%
print(uploadsql)
# Out:
# COPY gz2data(specobjid,dr8objid,dr7objid,ra,dec,rastring,decstring,sample,gz2_class,total_classifications,total_votes,t01_smooth_or_features_a01_smooth_count,t01_smooth_or_features_a01_smooth_weight,t01_smooth_or_features_a01_smooth_fraction,t01_smooth_or_features_a01_smooth_weighted_fraction,t01_smooth_or_features_a01_smooth_debiased,t01_smooth_or_features_a01_smooth_flag,t01_smooth_or_features_a02_features_or_disk_count,t01_smooth_or_features_a02_features_or_disk_weight,t01_smooth_or_features_a02_features_or_disk_fraction,t01_smooth_or_features_a02_features_or_disk_weighted_fraction,t01_smooth_or_features_a02_features_or_disk_debiased,t01_smooth_or_features_a02_features_or_disk_flag,t01_smooth_or_features_a03_star_or_artifact_count,t01_smooth_or_features_a03_star_or_artifact_weight,t01_smooth_or_features_a03_star_or_artifact_fraction,t01_smooth_or_features_a03_star_or_artifact_weighted_fraction,t01_smooth_or_features_a03_star_or_artifact_debiased,t01_smooth_or_features_a03_star_or_artifact_flag,t02_edgeon_a04_yes_count,t02_edgeon_a04_yes_weight,t02_edgeon_a04_yes_fraction,t02_edgeon_a04_yes_weighted_fraction,t02_edgeon_a04_yes_debiased,t02_edgeon_a04_yes_flag,t02_edgeon_a05_no_count,t02_edgeon_a05_no_weight,t02_edgeon_a05_no_fraction,t02_edgeon_a05_no_weighted_fraction,t02_edgeon_a05_no_debiased,t02_edgeon_a05_no_flag,t03_bar_a06_bar_count,t03_bar_a06_bar_weight,t03_bar_a06_bar_fraction,t03_bar_a06_bar_weighted_fraction,t03_bar_a06_bar_debiased,t03_bar_a06_bar_flag,t03_bar_a07_no_bar_count,t03_bar_a07_no_bar_weight,t03_bar_a07_no_bar_fraction,t03_bar_a07_no_bar_weighted_fraction,t03_bar_a07_no_bar_debiased,t03_bar_a07_no_bar_flag,t04_spiral_a08_spiral_count,t04_spiral_a08_spiral_weight,t04_spiral_a08_spiral_fraction,t04_spiral_a08_spiral_weighted_fraction,t04_spiral_a08_spiral_debiased,t04_spiral_a08_spiral_flag,t04_spiral_a09_no_spiral_count,t04_spiral_a09_no_spiral_weight,t04_spiral_a09_no_spiral_fraction,t04_spiral_a09_no_spiral_weighted_fraction,t04_spiral_a09_no_spiral_debiased,t04_spiral_a09_no_spiral_flag,t05_bulge_prominence_a10_no_bulge_count,t05_bulge_prominence_a10_no_bulge_weight,t05_bulge_prominence_a10_no_bulge_fraction,t05_bulge_prominence_a10_no_bulge_weighted_fraction,t05_bulge_prominence_a10_no_bulge_debiased,t05_bulge_prominence_a10_no_bulge_flag,t05_bulge_prominence_a11_just_noticeable_count,t05_bulge_prominence_a11_just_noticeable_weight,t05_bulge_prominence_a11_just_noticeable_fraction,t05_bulge_prominence_a11_just_noticeable_weighted_fraction,t05_bulge_prominence_a11_just_noticeable_debiased,t05_bulge_prominence_a11_just_noticeable_flag,t05_bulge_prominence_a12_obvious_count,t05_bulge_prominence_a12_obvious_weight,t05_bulge_prominence_a12_obvious_fraction,t05_bulge_prominence_a12_obvious_weighted_fraction,t05_bulge_prominence_a12_obvious_debiased,t05_bulge_prominence_a12_obvious_flag,t05_bulge_prominence_a13_dominant_count,t05_bulge_prominence_a13_dominant_weight,t05_bulge_prominence_a13_dominant_fraction,t05_bulge_prominence_a13_dominant_weighted_fraction,t05_bulge_prominence_a13_dominant_debiased,t05_bulge_prominence_a13_dominant_flag,t06_odd_a14_yes_count,t06_odd_a14_yes_weight,t06_odd_a14_yes_fraction,t06_odd_a14_yes_weighted_fraction,t06_odd_a14_yes_debiased,t06_odd_a14_yes_flag,t06_odd_a15_no_count,t06_odd_a15_no_weight,t06_odd_a15_no_fraction,t06_odd_a15_no_weighted_fraction,t06_odd_a15_no_debiased,t06_odd_a15_no_flag,t07_rounded_a16_completely_round_count,t07_rounded_a16_completely_round_weight,t07_rounded_a16_completely_round_fraction,t07_rounded_a16_completely_round_weighted_fraction,t07_rounded_a16_completely_round_debiased,t07_rounded_a16_completely_round_flag,t07_rounded_a17_in_between_count,t07_rounded_a17_in_between_weight,t07_rounded_a17_in_between_fraction,t07_rounded_a17_in_between_weighted_fraction,t07_rounded_a17_in_between_debiased,t07_rounded_a17_in_between_flag,t07_rounded_a18_cigar_shaped_count,t07_rounded_a18_cigar_shaped_weight,t07_rounded_a18_cigar_shaped_fraction,t07_rounded ...
# FROM '/home/colin/data/ssd240/zoo2MainSpecz.csv'
# DELIMITER ','
# CSV HEADER;

# %%
pg.run_admin(uploadsql)

# %%
import torch
print(torch.version.cuda)
print(torch.__version__)
